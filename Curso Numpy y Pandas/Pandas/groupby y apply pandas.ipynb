# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Groupby
# Agrupamientos por columna en la que vamos a trabajar sobre registros que tengan en comun dicha columna y poder aplicarle una funcion de agregacion: count(),sum(), mean(), max(), min(), etc.

# %%
df_books = pd.read_csv('bestsellers-with-categories.csv')
df_books.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
#la columna 'Author' deja de ser una columna y se convierte en indice
df_books.groupby('Author').count()
# Out:
#                             Name  User Rating  Reviews  Price  Year  Genre
# Author
# Abraham Verghese               2            2        2      2     2      2
# Adam Gasiewski                 1            1        1      1     1      1
# Adam Mansbach                  1            1        1      1     1      1
# Adir Levy                      1            1        1      1     1      1
# Admiral William H. McRaven     1            1        1      1     1      1
# ...                          ...          ...      ...    ...   ...    ...
# Walter Isaacson                3            3        3      3     3      3
# William Davis                  2            2        2      2     2      2
# William P. Young               2            2        2      2     2      2
# Wizards RPG Team               3            3        3      3     3      3
# Zhi Gang Sha                   2            2        2      2     2      2
#
# [248 rows x 6 columns]

# %%
#Author al ser indice podemos aplicar loc
df_books.groupby('Author').count().loc['William Davis']
# Out:
# Name           2
# User Rating    2
# Reviews        2
# Price          2
# Year           2
# Genre          2
# Name: William Davis, dtype: int64

# %%
#para que autor sea una columna debemos colocar reset_index()
df_books.groupby('Author').count().reset_index()
# Out:
#                          Author  Name  User Rating  Reviews  Price  Year  \
# 0              Abraham Verghese     2            2        2      2     2
# 1                Adam Gasiewski     1            1        1      1     1
# 2                 Adam Mansbach     1            1        1      1     1
# 3                     Adir Levy     1            1        1      1     1
# 4    Admiral William H. McRaven     1            1        1      1     1
# ..                          ...   ...          ...      ...    ...   ...
# 243             Walter Isaacson     3            3        3      3     3
# 244               William Davis     2            2        2      2     2
# 245            William P. Young     2            2        2      2     2
# 246            Wizards RPG Team     3            3        3      3     3
# 247                Zhi Gang Sha     2            2        2      2     2
#
#      Genre
# 0        2
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# ...

# %%
#podemos aplicar mas de una funcion de agregacion a la vez
df_books.groupby('Year').agg(['min','max'])
# Out:
#                                                    Name  \
#                                                     min
# Year
# 2009  Act Like a Lady, Think Like a Man: What Men Re...
# 2010  A Patriot's History of the United States: From...
# 2011                                  11/22/63: A Novel
# 2012  Barefoot Contessa Foolproof: Recipes You Can T...
# 2013                                          Allegiant
# 2014  A Game of Thrones / A Clash of Kings / A Storm...
# 2015  Adult Coloring Book: Stress Relieving Animal D...
# 2016                      10-Day Green Smoothie Cleanse
# 2017                             1984 (Signet Classics)
# 2018            12 Rules for Life: An Antidote to Chaos
# 2019  5,000 Awesome Facts (About Everything!) (Natio...
#
#                                                          \
#                                                     max
# Year
# 2009                          Where the Wild Things Are
# ...

# %%
#podemos especificar diversas funciones de agregacion para cada columna
df_books.groupby('Author').agg({'Reviews':['min','max'], 'User Rating': 'sum'})
# Out:
#                            Reviews        User Rating
#                                min    max         sum
# Author
# Abraham Verghese              4866   4866         9.2
# Adam Gasiewski                3113   3113         4.4
# Adam Mansbach                 9568   9568         4.8
# Adir Levy                     8170   8170         4.8
# Admiral William H. McRaven   10199  10199         4.7
# ...                            ...    ...         ...
# Walter Isaacson               3014   7827        13.7
# William Davis                 7497   7497         8.8
# William P. Young             19720  19720         9.2
# Wizards RPG Team             16990  16990        14.4
# Zhi Gang Sha                    37    220         9.2
#
# [248 rows x 3 columns]

# %%
#podemos agrupa por dos columnas
df_books.groupby(['Author', 'Year']).count()
# Out:
#                        Name  User Rating  Reviews  Price  Genre
# Author           Year
# Abraham Verghese 2010     1            1        1      1      1
#                  2011     1            1        1      1      1
# Adam Gasiewski   2017     1            1        1      1      1
# Adam Mansbach    2011     1            1        1      1      1
# Adir Levy        2019     1            1        1      1      1
# ...                     ...          ...      ...    ...    ...
# Wizards RPG Team 2017     1            1        1      1      1
#                  2018     1            1        1      1      1
#                  2019     1            1        1      1      1
# Zhi Gang Sha     2009     1            1        1      1      1
#                  2013     1            1        1      1      1
#
# [493 rows x 5 columns]

# %% [markdown]
# # Apply
# Nos permite crear funciones y aplicarlas sobre el dataframe entero o sobre una columna y es mucho mas rapido que aplicar un ciclo for sobre todas las filas o columnas

# %%
df_books.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
#definimos una funcion
def two_times(value):
    return value * 2

# %%
df_books['Rating 2'] = df_books['User Rating'].apply(two_times)
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
#lo mas habitual es usar funciones de tipo lambda
df_books['Rating_3'] = df_books['User Rating'].apply(lambda x: x*3)
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_books = pd.read_csv('bestsellers-with-categories.csv')
#aplicamos una funcion a todo el dataframe
df_books['Rating_2'] = df_books.apply(lambda x: x['User Rating'] * 2 if x['Genre'] == 'Fiction' else x['User Rating'], axis=1)
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...
