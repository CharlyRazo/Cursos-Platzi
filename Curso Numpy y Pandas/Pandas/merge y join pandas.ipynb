# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Concat
# Pegar un dataframe por debajo de otro, ya sea de forma horizontal compartiendo los mismos indices o de forma vertical, compartiendo las mismas columnas.

# %%
df1= pd.DataFrame({'A' : ['A0', 'A1', 'A2', 'A3'],
    'B' : ['B0', 'B1', 'B2', 'B3'],
    'C' : ['C0', 'C1', 'C2', 'C3'],
    'D' : ['D0', 'D1', 'D2', 'D3']})

df2 = pd.DataFrame({'A' : ['A4', 'A5', 'A6', 'A7'],
    'B' : ['B4', 'B5', 'B6', 'B7'],
    'C' : ['C4', 'C5', 'C6', 'C7'],
    'D' : ['D4', 'D5', 'D6', 'D7'],})

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
#al concatenar normalmente los indices se heredan del df original
#para evitar esto ignoramos los indices
pd.concat([df1,df2], ignore_index = True)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
#tambien podemos unirlo de forma horizontal
pd.concat([df1,df2],axis = 1 )
# Out:
#     A   B   C   D   A   B   C   D
# 0  A0  B0  C0  D0  A4  B4  C4  D4
# 1  A1  B1  C1  D1  A5  B5  C5  D5
# 2  A2  B2  C2  D2  A6  B6  C6  D6
# 3  A3  B3  C3  D3  A7  B7  C7  D7

# %%
# si no comparten una columna aun así se puede realizar el merge
df3 = df2.copy()
df3['E'] = ['E0', 'E1',' E2', 'E3']
pd.concat([df1,df3],ignore_index=True )
# Out:
#     A   B   C   D    E
# 0  A0  B0  C0  D0  NaN
# 1  A1  B1  C1  D1  NaN
# 2  A2  B2  C2  D2  NaN
# 3  A3  B3  C3  D3  NaN
# 4  A4  B4  C4  D4   E0
# 5  A5  B5  C5  D5   E1
# 6  A6  B6  C6  D6   E2
# 7  A7  B7  C7  D7   E3

# %% [markdown]
# # Merge
# Nos permite combinar dataframe al igual que en SQL cuando se combinan tablas, a traves de la busqueda de coincidencias en elementos de una columna  de un df sobre el otro

# %%
#creamos df con nombres caracteristicos
izq = pd.DataFrame({'key' : ['k0', 'k1', 'k2','k3'],
 'A' : ['A0', 'A1', 'A2','A3'],
'B': ['B0', 'B1', 'B2','B3']})

der = pd.DataFrame({'key' : ['k0', 'k1', 'k2','k3'],
 'C' : ['C0', 'C1', 'C2','C3'],
'D': ['D0', 'D1', 'D2','D3']})

# %%
izq
# Out:
#   key   A   B
# 0  k0  A0  B0
# 1  k1  A1  B1
# 2  k2  A2  B2
# 3  k3  A3  B3

# %%
der
# Out:
#   key   C   D
# 0  k0  C0  D0
# 1  k1  C1  D1
# 2  k2  C2  D2
# 3  k3  C3  D3

# %%
# Al dataframe izq le uniremos el dataframe por medio de un Merge Left
# se realiza el merge sobre una columna en especifica, en este caso 'key'
izq.merge(der, on='key')
# Out:
#   key   A   B   C   D
# 0  k0  A0  B0  C0  D0
# 1  k1  A1  B1  C1  D1
# 2  k2  A2  B2  C2  D2
# 3  k3  A3  B3  C3  D3

# %%
#mismos df pero con el nombre de la columna 'key' distinto
izq = pd.DataFrame({'key' : ['k0', 'k1', 'k2','k3'],
 'A' : ['A0', 'A1', 'A2','A3'],
'B': ['B0', 'B1', 'B2','B3']})


der = pd.DataFrame({'key2' : ['k0', 'k1', 'k2','k3'],
 'C' : ['C0', 'C1', 'C2','C3'],
'D': ['D0', 'D1', 'D2','D3']})

# %%
#hacer un merge left con columnas distintas
izq.merge(der, left_on='key', right_on ='key2' )
# Out:
#   key   A   B key2   C   D
# 0  k0  A0  B0   k0  C0  D0
# 1  k1  A1  B1   k1  C1  D1
# 2  k2  A2  B2   k2  C2  D2
# 3  k3  A3  B3   k3  C3  D3

# %%
#mismos df pero con el nombre de la columna 'key' distinto y un valor distinto
izq = pd.DataFrame({'key' : ['k0', 'k1', 'k2','k3'],
 'A' : ['A0', 'A1', 'A2','A3'],
'B': ['B0', 'B1', 'B2','B3']})


der = pd.DataFrame({'key2' : ['k0', 'k1', 'k2',np.nan],
 'C' : ['C0', 'C1', 'C2','C3'],
'D': ['D0', 'D1', 'D2','D3']})

# %%
#cuando hay valores nulos, hace un inner join por defecto
izq.merge(der, left_on='key', right_on ='key2' )
# Out:
#   key   A   B key2   C   D
# 0  k0  A0  B0   k0  C0  D0
# 1  k1  A1  B1   k1  C1  D1
# 2  k2  A2  B2   k2  C2  D2

# %%
#Podemos especificar el right join
izq.merge(der, left_on='key', right_on ='key2', how = 'right' )
# Out:
#    key    A    B key2   C   D
# 0   k0   A0   B0   k0  C0  D0
# 1   k1   A1   B1   k1  C1  D1
# 2   k2   A2   B2   k2  C2  D2
# 3  NaN  NaN  NaN  NaN  C3  D3

# %% [markdown]
# # Join

# %% [markdown]
# Hace lo mismo que el merge, pero en vez de buscar las coincidencias sobre lo columnas, lo hace sobre los elementos del indice

# %%
izq = pd.DataFrame({'A': ['A0','A1','A2'],
  'B':['B0','B1','B2']},
  index=['k0','k1','k2'])

der =pd.DataFrame({'C': ['C0','C1','C2'],
  'D':['D0','D1','D2']},
  index=['k0','k2','k3'])

# %%
izq
# Out:
#      A   B
# k0  A0  B0
# k1  A1  B1
# k2  A2  B2

# %%
der
# Out:
#      C   D
# k0  C0  D0
# k2  C1  D1
# k3  C2  D2

# %%
#hace un left join por default
izq.join(der)
# Out:
#      A   B    C    D
# k0  A0  B0   C0   D0
# k1  A1  B1  NaN  NaN
# k2  A2  B2   C1   D1

# %%
izq.join(der, how = 'right')
# Out:
#       A    B   C   D
# k0   A0   B0  C0  D0
# k2   A2   B2  C1  D1
# k3  NaN  NaN  C2  D2

# %%
izq.join(der, how = 'inner')
# Out:
#      A   B   C   D
# k0  A0  B0  C0  D0
# k2  A2  B2  C1  D1

# %%
izq.join(der, how = 'outer')
# Out:
#       A    B    C    D
# k0   A0   B0   C0   D0
# k1   A1   B1  NaN  NaN
# k2   A2   B2   C1   D1
# k3  NaN  NaN   C2   D2
